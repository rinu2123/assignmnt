# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\rinuf\\Downloads\\data.csv")
df
# Out:
#      Unnamed: 0  maxO3    T9   T12   T15  Ne9  Ne12  Ne15     Vx9    Vx12  \
# 0      20010601   87.0  15.6  18.5   NaN  4.0   4.0   8.0  0.6946 -1.7101
# 1      20010602   82.0   NaN   NaN   NaN  5.0   5.0   7.0 -4.3301 -4.0000
# 2      20010603   92.0  15.3  17.6  19.5  2.0   NaN   NaN  2.9544     NaN
# 3      20010604  114.0  16.2  19.7   NaN  1.0   1.0   0.0     NaN  0.3473
# 4      20010605   94.0   NaN  20.5  20.4  NaN   NaN   NaN -0.5000 -2.9544
# ..          ...    ...   ...   ...   ...  ...   ...   ...     ...     ...
# 107    20010925    NaN  13.3   NaN  17.8  3.0   5.0   NaN  0.0000 -1.0000
# 108    20010927   77.0  16.2  20.8   NaN  NaN   NaN   NaN -0.6946 -2.0000
# 109    20010928   99.0   NaN   NaN   NaN  NaN   NaN   NaN  1.5000  0.8682
# 110    20010929   83.0   NaN   NaN   NaN  NaN   5.0   3.0 -4.0000 -3.7588
# 111    20010930   70.0  15.7  18.6  20.7  7.0   NaN   7.0     NaN -1.0419
#
#        Vx15  maxO3v WindDirection
# 0   -0.6946    84.0         North
# ...

# %%
len(df)
# Out:
# 112

# %%
no_val=df[df.isnull().any(axis=1)] # shows dataframe with rows and columns having null values
no_val
# Out:
#      Unnamed: 0  maxO3    T9   T12   T15  Ne9  Ne12  Ne15     Vx9    Vx12  \
# 0      20010601   87.0  15.6  18.5   NaN  4.0   4.0   8.0  0.6946 -1.7101
# 1      20010602   82.0   NaN   NaN   NaN  5.0   5.0   7.0 -4.3301 -4.0000
# 2      20010603   92.0  15.3  17.6  19.5  2.0   NaN   NaN  2.9544     NaN
# 3      20010604  114.0  16.2  19.7   NaN  1.0   1.0   0.0     NaN  0.3473
# 4      20010605   94.0   NaN  20.5  20.4  NaN   NaN   NaN -0.5000 -2.9544
# ..          ...    ...   ...   ...   ...  ...   ...   ...     ...     ...
# 107    20010925    NaN  13.3   NaN  17.8  3.0   5.0   NaN  0.0000 -1.0000
# 108    20010927   77.0  16.2  20.8   NaN  NaN   NaN   NaN -0.6946 -2.0000
# 109    20010928   99.0   NaN   NaN   NaN  NaN   NaN   NaN  1.5000  0.8682
# 110    20010929   83.0   NaN   NaN   NaN  NaN   5.0   3.0 -4.0000 -3.7588
# 111    20010930   70.0  15.7  18.6  20.7  7.0   NaN   7.0     NaN -1.0419
#
#        Vx15  maxO3v WindDirection
# 0   -0.6946    84.0         North
# ...

# %%
#First Column

# %%
j=1   # variable representing column number
i=0   # Row number
for i in range(len(df)+1):  #Iterates the row till the end ie.len of the dataframe
    x=df.iloc[[i,j]]  # Value at specified row and column number 
    y=df.iloc[i+1,j]   # Value just one row down of x
    if y.isnull()==True:
        break
    elif abs(x-y)<=1:
        df.y=df.x
        j=j+1
    else:
        print("No result")

# %%
fig=plt.figure()
plt.plot(df.x)
plt.grid(axis='y',linewidth=1)
plt.title("Curve for maxO3")
plt.xlabel("Observed values and Imputed values")
plt.ylabel()
plt.legend()

# %%
# Second column

# %%
j=2
i=0
for i in range(len(df)+1):
    x=df.iloc[[i,j]]
    y=df.iloc[i+1,j]
    if y.isnull()==True:
        break
    elif abs(x-y)<=1:
        df.y=df.x
    else:
        print("No result")

# %%
fig=plt.figure()
plt.plot(df.x)
plt.grid(axis='y',linewidth=1)
plt.title("Curve for T9")
plt.xlabel("Observed values and Imputed values")
plt.ylabel()
plt.legend()

# %%
#Third Column

# %%
j=3
i=0
for i in range(len(df)+1):
    x=df.iloc[[i,j]]
    y=df.iloc[i+1,j]
    if y.isnull()==True:
        break
    elif abs(x-y)<=1:
        df.y=df.x
        j=j+1
    else:
        print("No result")

# %%
fig=plt.figure()
plt.plot(df.x)
plt.grid(axis='y',linewidth=1)
plt.title("Curve for T12")
plt.xlabel("Observed values and Imputed values")
plt.ylabel()
plt.legend()

# %%
#Fourth Column

# %%
j=4
i=0
for i in range(len(df)+1):
    x=df.iloc[[i,j]]
    y=df.iloc[i+1,j]
    if y.isnull()==True:
        break
    elif abs(x-y)<=1:
        df.y=df.x
        j=j+1
    else:
        print("No result")

# %%
fig=plt.figure()
plt.plot(df.x)
plt.grid(axis='y',linewidth=1)
plt.title("Curve for T15")
plt.xlabel("Observed values and Imputed values")
plt.ylabel()
plt.legend()

# %%
#Fifth Column

# %%
j=5
i=0
for i in range(len(df)+1):
    x=df.iloc[[i,j]]
    y=df.iloc[i+1,j]
    if y.isnull()==True:
        break
    elif abs(x-y)<=1:
        df.y=df.x
        j=j+1
    else:
        print("No result")

# %%
fig=plt.figure()
plt.plot(df.x)
plt.grid(axis='y',linewidth=1)
plt.title("Curve for Ne9")
plt.xlabel("Observed values and Imputed values")
plt.ylabel()
plt.legend()

# %%
#Sixth Column

# %%
j=6
i=0
for i in range(len(df)+1):
    x=df.iloc[[i,j]]
    y=df.iloc[i+1,j]
    if y.isnull()==True:
        break
    elif abs(x-y)<=1:
        df.y=df.x
        j=j+1
    else:
        print("No result")

# %%
fig=plt.figure()
plt.plot(df.x)
plt.grid(axis='y',linewidth=1)
plt.title("Curve for Ne12")
plt.xlabel("Observed values and Imputed values")
plt.ylabel()
plt.legend()

# %%
#Seventh Column

# %%
j=7
i=0
for i in range(len(df)+1):
    x=df.iloc[[i,j]]
    y=df.iloc[i+1,j]
    if y.isnull()==True:
        break
    elif abs(x-y)<=1:
        df.y=df.x
        j=j+1
    else:
        print("No result")

# %%
fig=plt.figure()
plt.plot(df.x)
plt.grid(axis='y',linewidth=1)
plt.title("Curve for Ne15")
plt.xlabel("Observed values and Imputed values")
plt.ylabel()
plt.legend()

# %%
#Eighth Column

# %%
j=8
i=0
for i in range(len(df)+1):
    x=df.iloc[[i,j]]
    y=df.iloc[i+1,j]
    if y.isnull()==True:
        break
    elif abs(x-y)<=1:
        df.y=df.x
        j=j+1
    else:
        print("No result")

# %%
fig=plt.figure()
plt.plot(df.x)
plt.grid(axis='y',linewidth=1)
plt.title("Curve for Vx9")
plt.xlabel("Observed values and Imputed values")
plt.ylabel()
plt.legend()

# %%
#Nineth Column

# %%
j=9
i=0
for i in range(len(df)+1):
    x=df.iloc[[i,j]]
    y=df.iloc[i+1,j]
    if y.isnull()==True:
        break
    elif abs(x-y)<=1:
        df.y=df.x
        j=j+1
    else:
        print("No result")

# %%
fig=plt.figure()
plt.plot(df.x)
plt.grid(axis='y',linewidth=1)
plt.title("Curve for Vx12")
plt.xlabel("Observed values and Imputed values")
plt.ylabel()
plt.legend()

# %%
#Tenth Column

# %%
j=10
i=0
for i in range(len(df)+1):
    x=df.iloc[[i,j]]
    y=df.iloc[i+1,j]
    if y.isnull()==True:
        break
    elif abs(x-y)<=1:
        df.y=df.x
        j=j+1
    else:
        print("No result")

# %%
fig=plt.figure()
plt.plot(df.x)
plt.grid(axis='y',linewidth=1)
plt.title("Curve for Vx15")
plt.xlabel("Observed values and Imputed values")
plt.ylabel()
plt.legend()

# %%
#Eleventh Column

# %%
j=11
i=0
for i in range(len(df)+1):
    x=df.iloc[[i,j]]
    y=df.iloc[i+1,j]
    if y.isnull()==True:
        break
    elif abs(x-y)<=1:
        df.y=df.x
        j=j+1
    else:
        print("No result")

# %%
fig=plt.figure()
plt.plot(df.x)
plt.grid(axis='y',linewidth=1)
plt.title("Curve for maxO3v ")
plt.xlabel("Observed values and Imputed values")
plt.ylabel()
plt.legend()
